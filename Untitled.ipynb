# %%
import pandas as pd
attributes = ['Not thinking only', 'Returned Reasoning', 'Configurable Temperature', 'Prompts can include reasoning']
models = {'gpt-5': [0,1,0,0], 'claude': [2,1,0,2], 'r1': [0,2,2,0], 'grok-3-mini': [0,2,2,0]}
dic = {}
for model in models.keys():
    dic[model] = {attributes[idx]: models[model][idx] for idx in range(len(attributes))}
df = pd.DataFrame.from_dict(dic)
print(df.style.background_gradient(cmap ='RdYlGn', vmin=-0.3, vmax=2.3)\
        .set_properties(**{'font-size': '20px'}).format(precision=2).to_latex())
# Out:
# \begin{tabular}{lrrrr}
#  & gpt-5 & claude & r1 & grok-3-mini \\
# Not thinking only & \background-color#db382b \color#f1f1f1 \font-size20px 0 & \background-color#249d53 \color#f1f1f1 \font-size20px 2 & \background-color#db382b \color#f1f1f1 \font-size20px 0 & \background-color#db382b \color#f1f1f1 \font-size20px 0 \\
# Returned Reasoning & \background-color#feffbe \color#000000 \font-size20px 1 & \background-color#feffbe \color#000000 \font-size20px 1 & \background-color#249d53 \color#f1f1f1 \font-size20px 2 & \background-color#249d53 \color#f1f1f1 \font-size20px 2 \\
# Configurable Temperature & \background-color#db382b \color#f1f1f1 \font-size20px 0 & \background-color#db382b \color#f1f1f1 \font-size20px 0 & \background-color#249d53 \color#f1f1f1 \font-size20px 2 & \background-color#249d53 \color#f1f1f1 \font-size20px 2 \\
# ...
